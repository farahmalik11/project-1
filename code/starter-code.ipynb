# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The University of California (UC) school system[<sup>^</sup>](#fn1) voted in 2020 to phase out standardized testing requirements as part of their admissions processes, stating that these tests add little value in predicting college performance and are discriminatory against low-income groups ([*1*](https://edsource.org/2019/lawsuits-seek-to-end-university-of-californias-sat-or-act-test-requirement-for-freshman-admission/620921#:~:text=The%20lawsuit%2C%20Kawika%20Smith%20v,income%2C%20black%20and%20Latino%20students)). As such, UC considered instating its own content-based standardized test in place of the SAT/ACT to assess student academic readiness ([*2*](https://regents.universityofcalifornia.edu/regmeet/may20/b4.pdf)) whilst remaining test-blind in the interim. As of June 2021, the UC school system has remained test-blind, not considering SAT/ACT scores for admission, and it remains to be seen if a new UC-specific test will come into fruition. As a large and influential institution, it is important that the UC school system consider all aspects of their decision to eliminate the SAT/ACT completely by 2025, ([*3*](https://www.calstate.edu/csu-system/news/Pages/Explained-Admissions-Without-the-SAT-or-ACT.aspx#:~:text=In%20March%202022%2C%20the%20CSU,not%20required%20for%20CSU%20applicants)) and examine the data around claims of fairness to low-income students and associations between standardized testing and college performance. They should then use these insights to inform the assumptions around any UC-based exam they may generate.
#
# The objective of this project is to begin a preliminary exploratory data analysis on 1) the relationship between standardized test scores and socioeconomic status, as defined by median income, across California counties, and on 2) the general relationship between standardized test scores and high school GPA as well as freshmen year of college GPA. This exploration will result in recommendations for where further resources may be directed, or whether it is appropriate to eliminate standardized testing from admissions processes altogether by 2025.
#
# <span id="fn1"> [<sup>^</sup>](#fn1)[*See here for list of 10 institutions*](https://www.csusb.edu/cal-soap/prepare-college/university-california-schools)</span>

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ---

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*4*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*5*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*6*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# As of April 2022, 86 institutions are test-blind and over 1,800 schools have become test-optional ([*7*](https://calmatters.org/education/higher-education/2022/03/csu-entrance-requirement/))([*8*](https://fairtest.org/test-optional-list/)), suggesting that institutions are becoming more comfortable making decisions with the lack of this formerly popular data point. Meanwhile, there remains the argument that the SAT and ACT do meaningfully predict college achievement and academic ability, and are enhanced by noncognitive variables such as conscientiousness, study habits, and attitude ([*9*](https://www.mdpi.com/2079-3200/7/4/26/)).
#
# Studies done by the CollegeBoard, the Academic Council’s Standardized Testing Task Force, and independent data scientists from organizations such as Insurify have all claimed that SAT scores predict college performance and retention, and high school GPA in conjunction with SAT/ACT scores can help admissions holistically select suitable candidates.([*10*](https://senate.universityofcalifornia.edu/_files/underreview/sttf-report.pdf))([*11*](https://www.mdpi.com/2079-3200/7/4/26))([*12*](https://www.powerfulprep.com/what-happens-if-the-ucs-drop-the-sat-and-act-requirement-permanently/))([*13*](https://insurify.com/car-insurance/knowledge/smartest-states-with-the-highest-gpas/))

# %% [markdown]
# ### Data Used
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`ETS_Sample_HSGPA_FYGPA.csv`](./data/ETS_Sample_HSGPA_FYGPA.csv): Anonymous student-level sample data on SAT scores, high school GPAs, and freshman-year-college GPAs for 1,000 students at an unnamed university ([*source*](https://www.openintro.org/data/index.php?data=satgpa))
# * [`Median_Income_by_State_2017-2019.csv`](./data/Median_Income_by_State_2017-2019.csv): 2017-2019 Median Income by State (three-year average) ([*source*](https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html))
# * [`Median_Income_CA_by_County_2017-2019.csv`](./data/Median_Income_CA_by_County_2017-2019.csv): 2017-2019 Median Income by California County ([*source*](https://data.ftb.ca.gov/California-Personal-Income-Tax/pit_B6-Comparison-By-County-Median-Income-/8dv7-kphc))

# %% [markdown]
# ### Current State and How We Got Here: A Brief Overview

# %% [markdown]
# The [*Smith v. Regents of the University of California*](https://publiccounsel.org/litigation/smith-v-regents-of-university-of-california/key-legal-documents/) lawsuit was filed in December 2019 by students, community organizations, and the Compton Unified School District ([*8*](https://publiccounsel.org/press-releases/milestone-settlement-in-higher-education-reached-between-students-and-university-of-california/)) ([*read the full amended complaint here*](https://publiccounsel.org/wp-content/uploads/2022/02/2020.06.15-Amended-Complaint.pdf)). The lawsuit challenged the use of the SAT and ACT in admissions decisions, claiming the tests were a discriminatory barrier to college access for minority students. The Standardized Testing Task Force (STTF) had been tasked with analyzing whether UC and it’s students were best served by the current testing practices, or if a modification of current practices should take place, such as another testing approach or overall elimination of testing ([*9*](https://senate.universityofcalifornia.edu/_files/underreview/sttf-report.pdf)). The lawsuit was settled in May 2021 with the University eliminating consideration of the testing from admissions and scholarship decisions, despite the STTF report arguing that such may risk lower student GPAs and lower probability of graduating.
#
# Even before UC schools could test their vision, the omission of standardized tests was played out during the COVID-19 pandemic, when many universities abandoned the requirement for admissions to mitigate impacts on students. Since then, some schools such as MIT have reinstated the exam, stating “Our ability to accurately predict student academic success is significantly improved by considering standardized testing … not having SATs/ACT scores to consider tends to raise socioeconomic barriers to demonstrating readiness for our education” ([*10*](https://www.wsj.com/articles/mit-leads-the-way-in-reinstating-the-sat-admissions-policies-standardized-testing-college-students-11649185773)). However, since the pandemic, and for some schools since even earlier, there has been a general decline in the number of colleges requiring SAT/ACTs in their applications.
#
# ![SAT_ACT_Req_Decline.jpeg](attachment:cac17b10-bde0-4fe5-b870-634b3b3b491a.jpeg "SAT and ACT Requirement Decline")
#
# Chart Source: [*here*](https://thehill.com/changing-america/enrichment/education/3758713-in-college-admissions-test-optional-is-the-new-normal/)
#
# The research remains mixed on whether it is appropriate or beneficial to exclude SATs and ACTs as one of many factors that go into college admissions.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
ls = [12, 75, 58, 30, 36, 98, 23]

def find_mean(nums):
    return sum(nums)/len(nums) 

find_mean(ls)
# Out:
# 47.42857142857143

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#def std(nums):
   # return (sum([(i - find_mean(nums))**2 for i in nums])*(1 / (len(nums)-1)))**0.5
    
#std(ls)

def std(nums):
    return (sum([(i - find_mean(nums))**2 for i in nums])*(1 / len(nums)))**0.5
    
std(ls)
# Out:
# 28.57499977681361

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def pct_convert(snum):
    return float(snum.replace('%', '')) / 100

pct_convert('60.5%')
# Out:
# 0.605

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math as math

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ---
# ## Cleaning ACT
# ---
# ### 2017

# %%
# import os
# os.getcwd()
# os.chdir('C:\\Users\\farah\\Documents\\General Assembly DSI\\DSI-508\\Projects\\Project 1\\project-1\\data')

# %%
# Display and Observe
act17 = pd.read_csv('./../data/act_2017.csv')
act17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act17.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
# Check Data Types
act17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# Fix Composite Character Value
act17['Composite'] = np.where(act17['Composite'] == "20.2x", float(20.2), act17['Composite']).astype(float)

# %%
act17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
# Make Participation as Float
act17['Participation'] = act17['Participation'].apply(pct_convert)

# %%
# Make Composite a Float
act17['Composite'] = act17['Composite'].astype(float)
act17.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
# Check Describe and Shape (using print to see both in same cell)
print(act17.describe())
print(act17.shape)
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.040385  21.509615
# std         0.318325   2.332132   1.963602   2.048672   3.151113   2.002083
# min         0.080000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%         0.310000  19.000000  19.400000  20.475000  19.900000  19.800000
# 50%         0.680000  20.550000  20.900000  21.700000  21.150000  21.400000
# 75%         1.000000  23.300000  23.100000  24.125000  22.525000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000
# (52, 7)

# %%
# Check Missing Values
act17.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
# Check String Values
act17['State'].value_counts(dropna=False)
# Out:
# National                1
# Alabama                 1
# Nebraska                1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Pennsylvania            1
# Rhode Island            1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Montana                 1
# Missouri                1
# Mississippi             1
# Hawaii                  1
# Alaska                  1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# ...

# %%
# Rename Columns
act17.columns = act17.columns.str.lower()

# %%
act17['year'] = '2017'

# %%
act17.head()
# Out:
#       state  participation  english  math  reading  science  composite  year
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0  2017
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2  2017
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8  2017
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7  2017
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4  2017

# %% [markdown]
# ### 2018

# %%
# Same for ACT 2018-2019
# Display and Observe
# Check Data Types
# Check Describe and Shape
# Check Missing Values
# Check String Values
# Rename Columns and Add Columns as Necessary

# %%
act18 = pd.read_csv('./../data/act_2018.csv')
act18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act18.tail()
# Out:
#             State Participation  Composite
# 47       Virginia           24%       23.9
# 48     Washington           24%       22.2
# 49  West Virginia           65%       20.3
# 50      Wisconsin          100%       20.5
# 51        Wyoming          100%       20.0

# %%
act18.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
# Fix Composite Character Value
act18['Composite'] = act18['Composite'].astype(float)

# %%
# Make Participation as Float
act18['Participation'] = act18['Participation'].apply(pct_convert)

# %%
act18.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
act18.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean        0.606731  21.544231
# std         0.345456   2.119417
# min         0.070000  17.700000
# 25%         0.270000  19.975000
# 50%         0.655000  21.300000
# 75%         1.000000  23.725000
# max         1.000000  25.600000

# %%
act18.shape
# Out:
# (52, 3)

# %%
act18.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act18['State'].value_counts()
# Out:
# Maine                   2
# Alabama                 1
# Montana                 1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Pennsylvania            1
# Rhode Island            1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Nebraska                1
# Missouri                1
# Alaska                  1
# Mississippi             1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# ...

# %%
act18.columns = act18.columns.str.lower()

# %%
act18['year'] = '2018'

# %%
act18.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       19.1  2018
# 1      Alaska           0.33       20.8  2018
# 2     Arizona           0.66       19.2  2018
# 3    Arkansas           1.00       19.4  2018
# 4  California           0.27       22.7  2018

# %% [markdown]
# ### 2019

# %%
# Same for ACT 2018-2019
# Display and Observe
# Check Data Types
# Check Describe and Shape
# Check Missing Values
# Check String Values
# Rename Columns and Add Columns as Necessary

# %%
act19 = pd.read_csv('./../data/act_2019.csv')
act19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act19.tail()
# Out:
#             State Participation  Composite
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8
# 51       National           52%       20.7

# %%
act19['Participation'] = act19['Participation'].apply(pct_convert)

# %%
act19.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
act19.columns = act19.columns.str.lower()

# %%
act19['year'] = '2019'

# %%
act19.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       18.9  2019
# 1      Alaska           0.38       20.1  2019
# 2     Arizona           0.73       19.0  2019
# 3    Arkansas           1.00       19.3  2019
# 4  California           0.23       22.6  2019

# %%
# Stack All 3 Years
act = pd.concat([act17, act18, act19])
act.shape
act

# Save CSV
act.to_csv('./../data/act_17-19.csv', index=False)

# %%
# Make Another Version of CSV that shows the mean composite score over three years and mean participation over three years, math, reading, sci, eng will remain 2017 figures
            # for math, reading, sci, eng we can choose any metric (sum, max, mean) and it should be fine because these are only populate for 2017
act_agg = act.groupby('state').agg({
    'participation': 'mean',
    'composite': 'mean',
    'english': 'sum',
    'math': 'sum',
    'reading': 'sum',
    'science': 'sum'})
act_agg

act_agg.to_csv('./../data/act_3yr_avg_by_state_17-19.csv')

# %% [markdown]
# ---
# ## Cleaning SAT
# ---
# ### 2017

# %%
# SAT 2017-2019
# Display and Observe
# Check Data Types
# Check Describe and Shape
# Check Missing Values
# Check String Values
# Rename Columns and Add Columns as Necessary

# %%
sat17 = pd.read_csv('./../data/sat_2017.csv')
sat17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat17.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat17['Participation'] = sat17['Participation'].apply(pct_convert)

# %%
sat17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat17.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat17.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  547.627451
# std         0.352766                           45.666901   84.909119
# min         0.020000                          482.000000   52.000000
# 25%         0.040000                          533.500000  522.000000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
sat17.shape
# Out:
# (51, 5)

# %%
sat17.rename(columns = {
    'Evidence-Based Reading and Writing': 'ebrw',
    }, inplace=True)

# %%
sat17.columns = sat17.columns.str.lower()

# %%
sat17['year'] = '2017'

# %%
sat17
# Out:
#                    state  participation  ebrw  math  total  year
# 0                Alabama           0.05   593   572   1165  2017
# 1                 Alaska           0.38   547   533   1080  2017
# 2                Arizona           0.30   563   553   1116  2017
# 3               Arkansas           0.03   614   594   1208  2017
# 4             California           0.53   531   524   1055  2017
# 5               Colorado           0.11   606   595   1201  2017
# 6            Connecticut           1.00   530   512   1041  2017
# 7               Delaware           1.00   503   492    996  2017
# 8   District of Columbia           1.00   482   468    950  2017
# 9                Florida           0.83   520   497   1017  2017
# 10               Georgia           0.61   535   515   1050  2017
# 11                Hawaii           0.55   544   541   1085  2017
# 12                 Idaho           0.93   513   493   1005  2017
# ...

# %% [markdown]
# ### 2018

# %%
sat18 = pd.read_csv('./../data/sat_2018.csv')
sat18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat18.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
#     Total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %%
sat18.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat18['Participation'] = sat18['Participation'].apply(pct_convert)

# %%
sat18.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat18.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat18.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.457451                          563.686275  556.235294
# std         0.373143                           47.502627   47.772623
# min         0.020000                          480.000000  480.000000
# 25%         0.045000                          534.500000  522.500000
# 50%         0.520000                          552.000000  544.000000
# 75%         0.775000                          610.500000  593.500000
# max         1.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %%
sat18.shape
# Out:
# (51, 5)

# %%
sat18.rename(columns = {
    'Evidence-Based Reading and Writing': 'ebrw',
    }, inplace=True)

# %%
sat18.columns = sat18.columns.str.lower()

# %%
sat18['year'] = '2018'

# %%
sat18.head()
# Out:
#         state  participation  ebrw  math  total  year
# 0     Alabama           0.06   595   571   1166  2018
# 1      Alaska           0.43   562   544   1106  2018
# 2     Arizona           0.29   577   572   1149  2018
# 3    Arkansas           0.05   592   576   1169  2018
# 4  California           0.60   540   536   1076  2018

# %% [markdown]
# ### 2019

# %%
sat19 = pd.read_csv('./../data/sat_2019.csv')
sat19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat19.tail()
# Out:
#             State Participation Rate  EBRW  Math  Total
# 48       Virginia                68%   567   551   1119
# 49     Washington                70%   539   535   1074
# 50  West Virginia                99%   483   460    943
# 51      Wisconsin                 3%   635   648   1283
# 52        Wyoming                 3%   623   615   1238

# %%
sat19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
# Temporarily change "--" to "0%" for function to work
sat19['Participation Rate'] = np.where(sat19['Participation Rate']  == "—", "0%", sat19['Participation Rate'])

# %%
# Use function to convert str into float
sat19['Participation Rate'] = sat19['Participation Rate'].apply(pct_convert)

# %%
# Overwrite 0% as None, this only affects the two states which had the "--"
# sat19['Participation Rate'] = np.where(sat19['Participation Rate']  == 0.0, None, sat19['Participation Rate'])

# Overwrite 0% as NaN instead, use replace instead of IF Excel logic - inspiration from Stack Overflow: https://stackoverflow.com/questions/44470695/how-to-replace-dashes-in-a-python-dataframe-by-nan
sat19['Participation Rate'] = sat19['Participation Rate'].replace(0.0, np.nan)

# %%
sat19.rename(columns = {
    'Participation Rate': 'participation',
    }, inplace=True)

# %%
sat19.columns = sat19.columns.str.lower()

# %%
sat19['year'] = '2019'

# %%
sat19.head()
# Out:
#         state  participation  ebrw  math  total  year
# 0     Alabama           0.07   583   560   1143  2019
# 1      Alaska           0.41   556   541   1097  2019
# 2     Arizona           0.31   569   565   1134  2019
# 3    Arkansas           0.06   582   559   1141  2019
# 4  California           0.63   534   531   1065  2019

# %%
# Stack All 3 Years
sat = pd.concat([sat17, sat18, sat19])
sat.shape
sat

# Save CSV
sat.to_csv('./../data/sat_17-19.csv', index=False)

# %%
# Make Another Version of CSV that shows the mean composite score over three years and mean participation over three years, math, reading, sci, eng will remain 2017 figures
            # for math, reading, sci, eng we can choose any metric (sum, max, mean) and it should be fine because these are only populate for 2017
sat_agg = sat.groupby('state').agg({
    'participation': 'mean',
    'ebrw': 'mean',
    'math': 'mean',
    'total': 'mean'})
sat_agg

sat_agg.to_csv('./../data/sat_3yr_avg_by_state_17-19.csv')

# %% [markdown]
# ---
# ## SAT California Cleaning
# ---

# %%
satca = pd.read_csv('./../data/sat_2019_ca.csv')
satca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
satca.shape
# Out:
# (2580, 26)

# %%
satca.head(1)
# Out:
#             CDS  CCode    CDCode     SCode RType                    SName  \
# 0  6.615981e+12    6.0  661598.0  630046.0     S  Colusa Alternative Home
#
#             DName   CName  Enroll12  NumTSTTakr12  ... NumERWBenchmark11  \
# 0  Colusa Unified  Colusa      18.0           0.0  ...               NaN
#
#   PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# 0               NaN                NaN                NaN
#
#    TotNumBothBenchmark12  PctBothBenchmark12 TotNumBothBenchmark11  \
# 0                    NaN                 NaN                   NaN
#
#   PctBothBenchmark11     Year Unnamed: 25
# 0                NaN  2018-19         NaN
#
# [1 rows x 26 columns]

# %%
# Drop columns we know we will not be using
satca.drop(columns=['CDS', 'CCode', 'CDCode', 'SCode', 'SName', 'DName', 'RType', 'TotNumBothBenchmark11', 
                   'PctBothBenchmark11', 'NumERWBenchmark11', 'PctERWBenchmark11', 'NumMathBenchmark11',
                   'PctMathBenchmark11', 'Unnamed: 25', 'Enroll11', 'NumTSTTakr11'], inplace=True)

# %%
# satca['NumERWBenchmark12'] = np.where(satca['NumERWBenchmark12']  == "*", None, satca['NumERWBenchmark12'])
# satca['PctERWBenchmark12'] = np.where(satca['PctERWBenchmark12']  == "*", None, satca['PctERWBenchmark12'])
# satca['NumMathBenchmark12'] = np.where(satca['NumMathBenchmark12']  == "*", None, satca['NumMathBenchmark12'])
# satca['PctMathBenchmark12'] = np.where(satca['PctMathBenchmark12']  == "*", None, satca['PctMathBenchmark12'])
# satca['TotNumBothBenchmark12'] = np.where(satca['TotNumBothBenchmark12']  == "*", None, satca['TotNumBothBenchmark12'])
3# satca['PctBothBenchmark12'] = np.where(satca['PctBothBenchmark12']  == "*", None, satca['PctBothBenchmark12'])
# Out:
# 3

# %%
# satca2 = satca.replace(np.nan, 0)
satca3 = satca.replace("*", np.nan)

# %%
satca3.head(10)
# Out:
#          CName  Enroll12  NumTSTTakr12 NumERWBenchmark12 PctERWBenchmark12  \
# 0       Colusa      18.0           0.0               NaN               NaN
# 1       Colusa      29.0          10.0               NaN               NaN
# 2  Los Angeles     206.0         102.0                31             30.39
# 3  Los Angeles     227.0         113.0                54             47.79
# 4  Los Angeles      18.0          14.0               NaN               NaN
# 5  Los Angeles     166.0         106.0                68             64.15
# 6       Orange     562.0         190.0               161             84.74
# 7    Riverside     114.0          17.0                 3             17.65
# 8     Imperial      91.0          27.0                14             51.85
# 9  Los Angeles      85.0          68.0                17             25.00
#
#   NumMathBenchmark12 PctMathBenchmark12 TotNumBothBenchmark12  \
# 0                NaN                NaN                   NaN
# ...

# %%
satca3.dtypes
# Out:
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# Year                      object
# dtype: object

# %%
# Clean up data types and make percents between 0-1
satca3['NumERWBenchmark12'] = satca3['NumERWBenchmark12'].astype(float)
satca3['PctERWBenchmark12'] = satca3['PctERWBenchmark12'].astype(float)/100
satca3['NumMathBenchmark12'] = satca3['NumMathBenchmark12'].astype(float)
satca3['PctMathBenchmark12'] = satca3['PctMathBenchmark12'].astype(float)/100
satca3['TotNumBothBenchmark12'] = satca3['TotNumBothBenchmark12'].astype(float)
satca3['PctBothBenchmark12'] = satca3['PctBothBenchmark12'].astype(float)/100

# %%
satca3.dtypes
# Out:
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12        float64
# PctERWBenchmark12        float64
# NumMathBenchmark12       float64
# PctMathBenchmark12       float64
# TotNumBothBenchmark12    float64
# PctBothBenchmark12       float64
# Year                      object
# dtype: object

# %%
satca3.isnull().sum()
# Out:
# CName                      1
# Enroll12                   1
# NumTSTTakr12               1
# NumERWBenchmark12        858
# PctERWBenchmark12        858
# NumMathBenchmark12       858
# PctMathBenchmark12       858
# TotNumBothBenchmark12    858
# PctBothBenchmark12       858
# Year                       1
# dtype: int64

# %%
satca3.isnull().mean()
# 33% of benchmark/performance data is missing, will need to work with the 67% available and maybe make note of missing data
# Out:
# CName                    0.000388
# Enroll12                 0.000388
# NumTSTTakr12             0.000388
# NumERWBenchmark12        0.332558
# PctERWBenchmark12        0.332558
# NumMathBenchmark12       0.332558
# PctMathBenchmark12       0.332558
# TotNumBothBenchmark12    0.332558
# PctBothBenchmark12       0.332558
# Year                     0.000388
# dtype: float64

# %%
satca3[satca3.isnull()]
# Out:
#      CName  Enroll12  NumTSTTakr12  NumERWBenchmark12  PctERWBenchmark12  \
# 0      NaN       NaN           NaN                NaN                NaN
# 1      NaN       NaN           NaN                NaN                NaN
# 2      NaN       NaN           NaN                NaN                NaN
# 3      NaN       NaN           NaN                NaN                NaN
# 4      NaN       NaN           NaN                NaN                NaN
# ...    ...       ...           ...                ...                ...
# 2575   NaN       NaN           NaN                NaN                NaN
# 2576   NaN       NaN           NaN                NaN                NaN
# 2577   NaN       NaN           NaN                NaN                NaN
# 2578   NaN       NaN           NaN                NaN                NaN
# 2579   NaN       NaN           NaN                NaN                NaN
#
#       NumMathBenchmark12  PctMathBenchmark12  TotNumBothBenchmark12  \
# ...

# %%
satca3.describe()
# Out:
#             Enroll12   NumTSTTakr12  NumERWBenchmark12  PctERWBenchmark12  \
# count    2579.000000    2579.000000        1722.000000        1722.000000
# mean      748.155487     264.274137         269.540070           0.683184
# std     10095.758681    3568.205236        2956.948278           0.203293
# min         0.000000       0.000000           0.000000           0.000000
# 25%        63.000000       5.000000          33.000000           0.546225
# 50%       171.000000      55.000000          79.000000           0.718100
# 75%       462.000000     161.000000         161.000000           0.851100
# max    489650.000000  170411.000000      116500.000000           1.000000
#
#        NumMathBenchmark12  PctMathBenchmark12  TotNumBothBenchmark12  \
# count         1722.000000         1722.000000            1722.000000
# mean           188.859466            0.457835             178.732288
# std           2063.412843            0.228773            1951.895654
# ...

# %%
satca3.rename(columns = {
    'CName': 'county',
    'Enroll12': 'n_enrolled', 
    'NumTSTTakr12': 'n_testtaker',
    'NumERWBenchmark12': 'n_ebrw_pass',
    'PctERWBenchmark12': 'pct_ebrw_pass',
    'NumMathBenchmark12': 'n_math_pass',
    'PctMathBenchmark12': 'pct_math_pass',
    'TotNumBothBenchmark12': 'n_both',
    'PctBothBenchmark12': 'pct_both',
    'Year': 'year'}, inplace=True)

# %%
# Keep only testtakers
satca3 = satca3[(satca3['n_testtaker'] > 0) & (satca3['n_enrolled'] > 0)] #had to add n_enrolled piece because there is anomalous data where n_enrolled = 0 but n_testtaker is > 0
satca3.describe()
# Out:
#           n_enrolled    n_testtaker    n_ebrw_pass  pct_ebrw_pass  \
# count    2303.000000    2303.000000    1722.000000    1722.000000
# mean      830.591403     295.945289     269.540070       0.683184
# std     10680.841259    3774.815882    2956.948278       0.203293
# min         1.000000       1.000000       0.000000       0.000000
# 25%        81.000000      14.000000      33.000000       0.546225
# 50%       220.000000      72.000000      79.000000       0.718100
# 75%       497.000000     177.500000     161.000000       0.851100
# max    489650.000000  170411.000000  116500.000000       1.000000
#
#         n_math_pass  pct_math_pass        n_both     pct_both
# count   1722.000000    1722.000000   1722.000000  1722.000000
# mean     188.859466       0.457835    178.732288     0.433717
# std     2063.412843       0.228773   1951.895654     0.228927
# min        0.000000       0.000000      0.000000     0.000000
# ...

# %%
# Aggregate and Save
sat_agg_cnty = satca3.groupby('county').agg({
    'n_enrolled': 'sum',
    'n_testtaker': 'sum',
    'n_ebrw_pass': 'sum',
    'n_math_pass': 'sum',
    'n_both': 'sum'}) #will have to regenerate the percents

sat_agg_cnty['pct_ebrw_pass'] = sat_agg_cnty['n_ebrw_pass'] / sat_agg_cnty['n_testtaker']
sat_agg_cnty['pct_math_pass'] = sat_agg_cnty['n_math_pass'] / sat_agg_cnty['n_testtaker']
sat_agg_cnty['pct_both_pass'] = sat_agg_cnty['n_both'] / sat_agg_cnty['n_testtaker']

sat_agg_cnty.to_csv('./../data/sat_ca_county.csv')

# %% [markdown]
# ---
# ## ACT California Cleaning
# ---

# %%
actca = pd.read_csv('./../data/act_2019_ca.csv')
actca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
# Drop columns we know we will not be using
actca.drop(columns=['CDS', 'CCode', 'CDCode', 'SCode', 'SName', 'DName', 'RType', 'Unnamed: 17', 'NumGE21', 'PctGE21'], inplace=True)

# %%
# actca = actca.replace(np.nan, None)
actca = actca.replace("*", np.nan)

# %%
actca
# Out:
#                CName  Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath  \
# 0          Riverside      18.0         0.0        NaN       NaN        NaN
# 1        Los Angeles      58.0         0.0        NaN       NaN        NaN
# 2               Kern      18.0         0.0        NaN       NaN        NaN
# 3        Santa Clara     463.0        53.0         23        22         22
# 4        Los Angeles     226.0        19.0         21        20         23
# ...              ...       ...         ...        ...       ...        ...
# 2305            Yuba     102.0         0.0        NaN       NaN        NaN
# 2306  San Bernardino     628.0        61.0         24        22         22
# 2307  San Bernardino     314.0        11.0        NaN       NaN        NaN
# 2308  San Bernardino      47.0         0.0        NaN       NaN        NaN
# 2309             NaN       NaN         NaN        NaN       NaN        NaN
#
#      AvgScrSci     Year
# 0          NaN  2018-19
# ...

# %%
actca.dtypes
# Out:
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead     object
# AvgScrEng      object
# AvgScrMath     object
# AvgScrSci      object
# Year           object
# dtype: object

# %%
actca['AvgScrRead'] = actca['AvgScrRead'].astype(float)
actca['AvgScrEng'] = actca['AvgScrEng'].astype(float)
actca['AvgScrMath'] = actca['AvgScrMath'].astype(float)
actca['AvgScrSci'] = actca['AvgScrSci'].astype(float)

# %%
actca.dtypes
# Out:
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead    float64
# AvgScrEng     float64
# AvgScrMath    float64
# AvgScrSci     float64
# Year           object
# dtype: object

# %%
actca.isnull().sum()
# Out:
# CName           1
# Enroll12        1
# NumTstTakr      1
# AvgScrRead    889
# AvgScrEng     889
# AvgScrMath    889
# AvgScrSci     889
# Year            1
# dtype: int64

# %%
actca.isnull().mean()
# 38.5% of benchmark/performance data is missing, will need to work with the 61.5% available and maybe make note of missing data
# Out:
# CName         0.000433
# Enroll12      0.000433
# NumTstTakr    0.000433
# AvgScrRead    0.384848
# AvgScrEng     0.384848
# AvgScrMath    0.384848
# AvgScrSci     0.384848
# Year          0.000433
# dtype: float64

# %%
actca.rename(columns = {
    'CName': 'county',
    'Enroll12': 'n_enrolled', 
    'NumTstTakr': 'n_testtaker',
    'AvgScrRead': 'avg_read',
    'AvgScrEng': 'avg_eng',
    'AvgScrMath': 'avg_math',
    'AvgScrSci': 'avg_sci',
    'Year': 'year'}, inplace=True)

# %%
# Keep only testtakers
actca = actca[(actca['n_testtaker'] > 0) & (actca['n_enrolled'] > 0)] #had to add n_enrolled piece because there is anomalous data where n_enrolled = 0 but n_testtaker is > 0
actca.describe()
# Out:
#           n_enrolled   n_testtaker     avg_read      avg_eng     avg_math  \
# count    1952.000000   1952.000000  1420.000000  1420.000000  1420.000000
# mean      965.695184    169.358094    22.079577    21.208451    21.419718
# std     11596.673268   1974.643843     3.671117     4.043657     3.379648
# min         3.000000      1.000000    12.000000    10.000000    14.000000
# 25%       109.000000     13.000000    19.000000    18.000000    19.000000
# 50%       305.000000     41.000000    22.000000    21.000000    21.000000
# 75%       537.250000    100.250000    25.000000    24.000000    24.000000
# max    489650.000000  82668.000000    32.000000    32.000000    32.000000
#
#            avg_sci
# count  1420.000000
# mean     21.360563
# std       3.208449
# min      12.000000
# 25%      19.000000
# 50%      21.000000
# 75%      24.000000
# max      31.000000

# %%
actca.head()
# Out:
#         county  n_enrolled  n_testtaker  avg_read  avg_eng  avg_math  avg_sci  \
# 3  Santa Clara       463.0         53.0      23.0     22.0      22.0     23.0
# 4  Los Angeles       226.0         19.0      21.0     20.0      23.0     22.0
# 5  Los Angeles        65.0         33.0      15.0     15.0      17.0     16.0
# 6  Los Angeles       126.0         16.0      18.0     18.0      18.0     17.0
# 7  Los Angeles        14.0          1.0       NaN      NaN       NaN      NaN
#
#       year
# 3  2018-19
# 4  2018-19
# 5  2018-19
# 6  2018-19
# 7  2018-19

# %%
# Aggregate and Save
act_agg_cnty = actca.groupby('county').agg({
    'n_enrolled': 'sum',
    'n_testtaker': 'sum',
    'avg_read': 'mean',
    'avg_eng': 'mean',
    'avg_math': 'mean',
    'avg_sci': 'mean'}) #will have to generate composite

# act_agg_cnty['composite'] = round((act_agg_cnty['avg_read'] + act_agg_cnty['avg_eng'] + act_agg_cnty['avg_math'] + act_agg_cnty['avg_sci'])/4)
act_agg_cnty['composite'] = (act_agg_cnty['avg_read'] + act_agg_cnty['avg_eng'] + act_agg_cnty['avg_math'] + act_agg_cnty['avg_sci'])/4
act_agg_cnty

act_agg_cnty.to_csv('./../data/act_ca_county.csv')

# %% [markdown]
# ---
# ## Cleaning Median Income Data by California County
# ---

# %%
mico = pd.read_csv('./../data/Median_Income_CA_by_County_2017-2019.csv', thousands=',')
mico.head()
 #thousands option researched on Stack Overflow: https://stackoverflow.com/questions/37439933/pandas-reading-csv-data-formatted-with-comma-for-thousands-separator
# Out:
#    Taxable Year       County  Population  All Returns          AGI  \
# 0          2019    El Dorado    192012.0        89756   8361219000
# 1          2018         Lake     65020.0        23901   1200985491
# 2          2019  San Joaquin    776068.0       324751  20045629000
# 3          2017   Stanislaus    550505.0       217804  12150948000
# 4          2019         Napa    138711.0        66934   7265285000
#
#    Median Income  Median Rank  Joint Returns  Joint Returns Median Income  \
# 0          51895          8.0          41384                       103696
# 1          32486         50.0           8894                        58138
# 2          39499         29.0         117742                        78594
# 3          35396         35.0          84747                        65696
# 4          51525          9.0          26976                        99428
#
#    Joint Returns Median Rank  Tax Assessed   Latitude   Longitude  \
# ...

# %%
# Drop columns we know we will not be using
mico.drop(columns=['All Returns', 'AGI', 'Joint Returns', 'Joint Returns Median Income', 'Median Rank', 'Joint Returns Median Rank', 'Tax Assessed', 'New Georeferenced Column'], inplace=True)

# %%
mico.describe()
# Out:
#        Taxable Year    Population  Median Income    Latitude   Longitude
# count    183.000000  1.740000e+02     183.000000  183.000000  183.000000
# mean    2018.000000  6.851193e+05   40384.284153   35.958091 -114.839606
# std        0.818737  1.481137e+06   10592.822950    8.467434   26.260545
# min     2017.000000  1.115000e+03   14600.000000    0.000000 -123.892004
# 25%     2017.000000  4.459300e+04   33577.000000   36.324707 -122.078097
# 50%     2018.000000  1.885190e+05   37379.000000   37.988180 -120.943072
# 75%     2019.000000  7.576850e+05   44522.500000   39.167981 -119.698820
# max     2019.000000  1.026994e+07   74077.000000   41.713682    0.000000

# %%
# Keep latitude and longtitude in case we want to use it in a map or something at some point
mico['Latitude'] = mico['Latitude'].astype(float)
mico['Longitude'] = mico['Longitude'].astype(float)

# %%
mico.dtypes
# Out:
# Taxable Year       int64
# County            object
# Population       float64
# Median Income      int64
# Latitude         float64
# Longitude        float64
# dtype: object

# %%
mico.isnull().sum()
# Out:
# Taxable Year     0
# County           0
# Population       9
# Median Income    0
# Latitude         0
# Longitude        0
# dtype: int64

# %%
mico[mico['Population'].isnull()]
# Out:
#      Taxable Year                 County  Population  Median Income  Latitude  \
# 24           2017  Resident Out-of-State         NaN          34108       0.0
# 26           2018            Unallocated         NaN          29579       0.0
# 68           2017            Nonresident         NaN          14600       0.0
# 86           2019            Unallocated         NaN          21500       0.0
# 108          2017            Unallocated         NaN          46640       0.0
# 109          2018  Resident Out-of-State         NaN          35030       0.0
# 154          2018            Nonresident         NaN          16109       0.0
# 167          2019  Resident Out-of-State         NaN          19946       0.0
# 174          2019            Nonresident         NaN          19434       0.0
#
#      Longitude
# 24         0.0
# 26         0.0
# 68         0.0
# 86         0.0
# 108        0.0
# 109        0.0
# 154        0.0
# 167        0.0
# 174        0.0

# %%
#take out rows where there is no population, these aren't associated with CA counties (they are listed as resident-out-of-staate, nonresident, unallocated)
mico = mico[~mico['Population'].isnull()]
mico.describe()
# Out:
#        Taxable Year    Population  Median Income    Latitude   Longitude
# count    174.000000  1.740000e+02     174.000000  174.000000  174.000000
# mean    2018.000000  6.851193e+05   41111.367816   37.817992 -120.779585
# std        0.818853  1.481137e+06   10097.367367    2.164036    1.979127
# min     2017.000000  1.115000e+03   25785.000000   32.789640 -123.892004
# 25%     2017.000000  4.459300e+04   33797.000000   36.633503 -122.164352
# 50%     2018.000000  1.885190e+05   37949.000000   38.108172 -121.049628
# 75%     2019.000000  7.576850e+05   44597.250000   39.271295 -119.890430
# max     2019.000000  1.026994e+07   74077.000000   41.713682 -114.751536

# %%
mico.isnull().sum()
# Out:
# Taxable Year     0
# County           0
# Population       0
# Median Income    0
# Latitude         0
# Longitude        0
# dtype: int64

# %%
mico.rename(columns = {
    'Taxable Year': 'year',
    'County': 'county',
    'Population': 'population', 
    'Median Income': 'med_income',
    'Latitude': 'latitude',
    'Longitude': 'longitude'}, inplace=True)

# %%
mico.head()
# Out:
#    year       county  population  med_income   latitude   longitude
# 0  2019    El Dorado    192012.0       51895  38.763942 -120.606059
# 1  2018         Lake     65020.0       32486  39.065005 -122.657019
# 2  2019  San Joaquin    776068.0       39499  37.933703 -121.344401
# 3  2017   Stanislaus    550505.0       35396  37.501488 -121.216480
# 4  2019         Napa    138711.0       51525  38.459382 -122.332856

# %%
# Merge in median income to ACT and SAT county data

# first aggregate median income data, take 3 year average
mi_cnty = mico.groupby('county').agg({
    'population': 'mean',
    'med_income': 'mean',
    'latitude': 'max',
    'longitude': 'max'}) 

# Merge, save, overwrite original ACT dataset
act_agg_cnty1 = pd.merge(act_agg_cnty, mi_cnty, on='county', how='left')

# Drop counties where either the ACT score is not available or the median income is not available
act_agg_cnty2 = act_agg_cnty1[act_agg_cnty1['composite'].notnull() & act_agg_cnty1['med_income'].notnull()]
act_agg_cnty2 = act_agg_cnty2.reset_index() #reset index so county still appears in dataset as a column rather than index

act_agg_cnty2.to_csv('./../data/act_ca_county.csv')

# %%
# Merge, save, overwrite original SAT dataset
sat_agg_cnty1 = pd.merge(sat_agg_cnty, mi_cnty, on='county', how='left')
sat_agg_cnty2 = sat_agg_cnty1[sat_agg_cnty1['med_income'].notnull()]
sat_agg_cnty2 = sat_agg_cnty2.reset_index() #reset index so county still appears in dataset as a column rather than index

sat_agg_cnty2.to_csv('./../data/sat_ca_county.csv')

# %%
# Save the national CA scores in case you want to reference later
act_agg_cnty1 = act_agg_cnty1.reset_index()   #reset index so county still appears in dataset as a column rather than index, and we can store it's values below
act_agg_cnty1[act_agg_cnty1['county'] == 'State of California']

#reset_index researched on Stack Overflow: https://towardsdatascience.com/wide-to-long-data-how-and-when-to-use-pandas-melt-stack-and-wide-to-long-7c1e0f462a98
# Out:
#                  county  n_enrolled  n_testtaker  avg_read  avg_eng  avg_math  \
# 49  State of California    489650.0      82668.0      22.0     22.0      22.0
#
#     avg_sci  composite  population  med_income  latitude  longitude
# 49     22.0       22.0         NaN         NaN       NaN        NaN

# %%
n_enr_ca = 489650
n_tstkr_act_ca = 82668
avg_read_act_ca = 22
avg_eng_act_ca = 22
avg_math_act_ca = 22
avg_sci_act_ca = 22
composite_act_ca = 22

# %%
sat_agg_cnty1 = sat_agg_cnty1.reset_index()  #reset index so county still appears in dataset as a column rather than index, and we can store it's values below
sat_agg_cnty1[sat_agg_cnty1['county'] == 'State of California']
# Out:
#                  county  n_enrolled  n_testtaker  n_ebrw_pass  n_math_pass  \
# 49  State of California    489650.0     170411.0     116500.0      81551.0
#
#      n_both  pct_ebrw_pass  pct_math_pass  pct_both_pass  population  \
# 49  77178.0       0.683641       0.478555       0.452893         NaN
#
#     med_income  latitude  longitude
# 49         NaN       NaN        NaN

# %%
n_enr_ca = 489650
n_tstkr_sat_ca = 170411
n_ebrw_sat_ca = 116500
n_math_sat_ca = 81551
n_both_sat_ca = 77178

# %% [markdown]
# ---
# ## Cleaning Median Income Data by California State
# ---

# %%
mist = pd.read_csv('./../data/Median_Income_by_State_2017-2019.csv', thousands=',')
mist.head()
# Out:
#            State  Median income  Standard error
# 0  United States          69516             336
# 1        Alabama          56552            1519
# 2         Alaska          81146            3513
# 3        Arizona          69361            1946
# 4       Arkansas          55499            1479

# %%
# Drop columns we know we will not be using
mist.drop(columns=['Standard error'], inplace=True)

# %%
mist.describe()
# Out:
#        Median income
# count      52.000000
# mean    70440.634615
# std     11105.569177
# min     47153.000000
# 25%     63034.500000
# 50%     69611.000000
# 75%     78935.250000
# max     95016.000000

# %%
mist.dtypes
# Out:
# State            object
# Median income     int64
# dtype: object

# %%
mist.isnull().sum()
# Out:
# State            0
# Median income    0
# dtype: int64

# %%
mist.rename(columns = {
    'State': 'state',
    'Median income': 'med_income'}, inplace=True)

# %%
mist.head()
# Out:
#            state  med_income
# 0  United States       69516
# 1        Alabama       56552
# 2         Alaska       81146
# 3        Arizona       69361
# 4       Arkansas       55499

# %%
# Merge med income into our SAT and ACT state level data
sat_agg2 = pd.merge(sat_agg, mist, on='state', how='left')
sat_agg2.to_csv('./../data/sat_3yr_avg_by_state_17-19_w_mi.csv', index=False)

# %%
act_agg2 = pd.merge(act_agg, mist, on='state', how='left')
act_agg2.to_csv('./../data/act_3yr_avg_by_state_17-19_w_mi.csv', index=False)

# %% [markdown]
# ---
# ### Cleaning Educational Testing Services Data
# ---

# %%
ets = pd.read_csv('./../data/ETS_Sample_HSGPA_FYGPA.csv')
ets.head()
# Out:
#       sex  sat_verbal  sat_math  sat_total  gpa_hs  gpa_fy
# 0    Male          65        62        127    3.40    3.18
# 1  Female          58        64        122    4.00    3.33
# 2  Female          56        60        116    3.75    3.25
# 3    Male          42        53         95    3.75    2.42
# 4    Male          55        52        107    4.00    2.63

# %%
ets.dtypes
# Out:
# sex            object
# sat_verbal      int64
# sat_math        int64
# sat_total       int64
# gpa_hs        float64
# gpa_fy        float64
# dtype: object

# %%
ets.isnull().sum()
# Out:
# sex           0
# sat_verbal    0
# sat_math      0
# sat_total     0
# gpa_hs        0
# gpa_fy        0
# dtype: int64

# %%
ets.describe()
# no further cleaning needed
# Out:
#        sat_verbal     sat_math    sat_total       gpa_hs       gpa_fy
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     48.93400    54.395000   103.329000     3.198100     2.467950
# std       8.23392     8.450111    14.287368     0.541647     0.740805
# min      24.00000    29.000000    53.000000     1.800000     0.000000
# 25%      43.00000    49.000000    93.000000     2.800000     1.980000
# 50%      49.00000    55.000000   103.000000     3.200000     2.465000
# 75%      54.00000    60.000000   113.000000     3.700000     3.020000
# max      76.00000    77.000000   144.000000     4.500000     4.000000

# %%
ets.to_csv('./../data/ETS_sample.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county**|*string*|ACT_CA_COUNTY|The California county |
# |**n_enrolled**|*integer*|ACT_CA_COUNTY|The number of students across the various schools in the CA county (based on 2019 data)|
# |**n_testtaker**|*integer*|ACT_CA_COUNTY|The number of students across the various schools in the CA county who took the ACT (based on 2019 data)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county**|*object*|ACT_CA_COUNTY|The California county |
# |**n_enrolled**|*integer*|ACT_CA_COUNTY|The number of students across the various schools in the CA county (based on 2019 data)|
# |**n_testtaker**|*integer*|ACT_CA_COUNTY|The number of students across the various schools in the CA county who took the ACT (based on 2019 data)|
# |**avg_read**|*float*|ACT_CA_COUNTY|The average ACT Reading score of students across schools within the CA county (based on 2019 data)|
# |**avg_eng**|*float*|ACT_CA_COUNTY|The average ACT English score of students across schools within the CA county (based on 2019 data))|
# |**avg_math**|*float*|ACT_CA_COUNTY|The average ACT Math score of students across schools within the CA county (based on 2019 data)|
# |**avg_sci**|*float*|ACT_CA_COUNTY|The average ACT Science score of students across schools within the CA county (based on 2019 data)|
# |**composite**|*float*|ACT_CA_COUNTY|The average composite ACT score of schools in the CA county (based on 2019 data, calculated as the average of the county level Reading, English, Math, and Science score)|
# |**population**|*float*|ACT_CA_COUNTY|The three-year-average (2017-2019) CA county population|
# |**med_income**|*float*|ACT_CA_COUNTY|The three-year-average (2017-2019) median income per CA county of students across the various schools in the CA county|
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county**|*object*|SAT_CA_COUNTY|The California county |
# |**n_enrolled**|*integer*|SAT_CA_COUNTY|The number of students across the various schools in the CA county (based on 2019 data)|
# |**n_testtaker**|*integer*|SAT_CA_COUNTY|The number of students across the various schools in the CA county who took the SAT (based on 2019 data)|
# |**n_ebrw_pass**|*float*|SAT_CA_COUNTY|The number of students who met or exceeded the benchmark for SAT Evidence-Based Reading and Writing (EBRW) (based on 2019 data)|
# |**n_math_pass**|*float*|SAT_CA_COUNTY|The number of students who met or exceeded the benchmark for SAT Math (based on 2019 data)|
# |**n_both**|*float*|SAT_CA_COUNTY|The number of students who met or exceeded the benchmark for both SAT EBRW and SAT Math (based on 2019 data)|
# |**pct_ebrw_pass**|*float*|SAT_CA_COUNTY|The percent of students who met or exceeded the benchmark for SAT EBRW (based on 2019 data)|
# |**pct_math_pas**|*float*|SAT_CA_COUNTY|The percent of students who met or exceeded the benchmark for SAT Math (based on 2019 data)|
# |**pct_both**|*float*|SAT_CA_COUNTY|The percent of students who met or exceeded the benchmark for both SAT EBRW and SAT Math(based on 2019 data)|
# |**population**|*float*|SAT_CA_COUNTY|The three-year-average (2017-2019) CA county population|
# |**med_income**|*float*|SAT_CA_COUNTY|The three-year-average (2017-2019) median income per CA county of students across the various schools in the CA county|
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**sex**|*object*|ETS_SAMPLE|The sex of the student (Male/Female) among a 1,000 student sample|
# |**sat_verbal**|*integer*|ETS_SAMPLE|The SAT Evidence-Based Reading and Writing score of the student among a 1,000 student sample (numbers are divided by 100)|
# |**sat_math**|*integer*|ETS_SAMPLE|The SAT Math score of the student among a 1,000 student sample (numbers are divided by 100)|
# |**sat_total**|*integer*|ETS_SAMPLE|The total SAT score of the student among a 1,000 student sample (numbers are divided by 100)|
# |**gpa_hs**|*float*|ETS_SAMPLE|The high school GPA of the student among a 1,000 student sample (numbers are divided by 100)|
# |**gpa_fy**|*float*|ETS_SAMPLE|The freshmen-year-college GPA of the student among a 1,000 student sample (numbers are divided by 100)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ---
# ### Summary Statistics
# ---

# %%
act_agg_cnty2.describe()
# Out:
#           n_enrolled   n_testtaker   avg_read    avg_eng   avg_math  \
# count      54.000000     54.000000  54.000000  54.000000  54.000000
# mean    25815.537037   4590.148148  22.501258  21.360831  21.589197
# std     51379.983931   9765.253080   2.199736   2.313344   1.948428
# min       249.000000     45.000000  17.400000  15.000000  17.000000
# 25%      2025.750000    219.000000  20.693515  19.447727  20.020833
# 50%      7428.500000   1351.500000  22.850000  21.750000  22.000000
# 75%     23544.250000   3849.750000  24.194643  23.280952  23.075000
# max    330158.000000  62004.000000  26.181818  25.636364  24.842105
#
#          avg_sci  composite    population    med_income   latitude   longitude
# count  54.000000  54.000000  5.400000e+01     54.000000  54.000000   54.000000
# mean   21.589073  21.760090  7.349385e+05  41437.549383  37.658913 -120.737589
# std     1.755265   2.028769  1.533029e+06  10362.893217   2.150706    2.013651
# ...

# %%
sat_agg_cnty2.describe()
# Out:
#           n_enrolled    n_testtaker   n_ebrw_pass   n_math_pass        n_both  \
# count      57.000000      57.000000     57.000000     57.000000     57.000000
# mean    24968.456140    8967.561404   6099.087719   4274.824561   4045.596491
# std     51278.207833   21392.033281  13612.990990   9249.663181   8713.939475
# min        65.000000      15.000000      0.000000      0.000000      0.000000
# 25%      1420.000000     273.000000    215.000000    153.000000    146.000000
# 50%      6630.000000    1812.000000   1592.000000   1036.000000    985.000000
# 75%     21466.000000    7119.000000   5088.000000   4162.000000   4027.000000
# max    336832.000000  146016.000000  90078.000000  59300.000000  55597.000000
#
#        pct_ebrw_pass  pct_math_pass  pct_both_pass    population  \
# count      57.000000      57.000000      57.000000  5.700000e+01
# mean        0.680799       0.479958       0.456892  6.971191e+05
# std         0.176718       0.165791       0.162938  1.500162e+06
# ...

# %%
ets.describe()
# Out:
#        sat_verbal     sat_math    sat_total       gpa_hs       gpa_fy
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     48.93400    54.395000   103.329000     3.198100     2.467950
# std       8.23392     8.450111    14.287368     0.541647     0.740805
# min      24.00000    29.000000    53.000000     1.800000     0.000000
# 25%      43.00000    49.000000    93.000000     2.800000     1.980000
# 50%      49.00000    55.000000   103.000000     3.200000     2.465000
# 75%      54.00000    60.000000   113.000000     3.700000     3.020000
# max      76.00000    77.000000   144.000000     4.500000     4.000000

# %% [markdown]
# ---
# ### Generating Dictionary Comprehensions of StDev
# ---

# %%
sd_act_cnty = {i: std(act_agg_cnty2[i]) for i in act_agg_cnty2 if act_agg_cnty2[i].dtypes == "int64" or act_agg_cnty2[i].dtypes == "float64"}
sd_sat_cnty = {i: std(sat_agg_cnty2[i]) for i in sat_agg_cnty2 if sat_agg_cnty2[i].dtypes == "int64" or sat_agg_cnty2[i].dtypes == "float64"}
sd_ets = {i: std(ets[i]) for i in ets if ets[i].dtypes == "int64" or ets[i].dtypes == "float64"}

# nums2 = [i for i in nums if not np.isnan(i)]

# %%
sd_act_cnty
# the standard deviation of the number of students and testtakers across the counties is large (~51.4K and 9.7K, respectively)
# all ACT scores had a spread of ~2 points
# Out:
# {'n_enrolled': 50902.02020392924,
#  'n_testtaker': 9674.411541884901,
#  'avg_read': 2.179272406498825,
#  'avg_eng': 2.291824414197673,
#  'avg_math': 1.9303027874783099,
#  'avg_sci': 1.738936220875913,
#  'composite': 2.0098965641083413,
#  'population': 1518767.8837624034,
#  'med_income': 10266.492114749397,
#  'latitude': 2.1306990698348076,
#  'longitude': 1.9949188682954255}

# %%
sd_sat_cnty
# standard deviations are large for all numeric non-percents data
#longitude and latitude retained in case we wanted to eventually plot any findings on a map
# Out:
# {'n_enrolled': 50826.40864887871,
#  'n_testtaker': 21203.55354280789,
#  'n_ebrw_pass': 13493.05040522414,
#  'n_math_pass': 9168.166762978448,
#  'n_both': 8637.16318125557,
#  'pct_ebrw_pass': 0.17516133061942382,
#  'pct_math_pass': 0.16433055107846092,
#  'pct_both_pass': 0.16150202232318953,
#  'population': 1486944.4292905233,
#  'med_income': 10051.182878500946,
#  'latitude': 2.174218592760512,
#  'longitude': 1.9855547294176188}

# %%
sd_ets
# SAT reading and writing had a spread of ~8 points, while the total score standard deviation was nearly twice that
# Out:
# {'sat_verbal': 8.229802184742955,
#  'sat_math': 8.445885092753748,
#  'sat_total': 14.280222652325856,
#  'gpa_hs': 0.5413765694966857,
#  'gpa_fy': 0.7404346679484975}

# %% [markdown]
# ---
# ### Data Exploration
# ---
#
# ##### <span style='color:purple'>The standardized test that this exploration will focus on is the ACT, as the data available is average scores. SAT data, indicating the number/percent of students meeting testing benchmarks, may be used later as informed by the initial exploration. SAT data will be used for exploring the relationship between the test and college performance. Among the ACT data, we will be focusing on the composite score, as the summary statistics do not suggest there are meaningful differences to start exploring in terms of performance across different subject areas (Math, Science, English, and Reading).</span>
#
# ##### <span style='color:blue'> _Insights in blue_ </span>

# %% [markdown]
# #### Which CA Counties Have the Highest/Lowest Median Income

# %%
#act_agg_cnty2.sort_values(['med_income'], ascending=False).head(10)
act_agg_cnty2.loc[:,["county","med_income"]].sort_values(['med_income'], ascending=False).head(10)
# Out:
#            county    med_income
# 18          Marin  71605.666667
# 34  San Francisco  67692.666667
# 39    Santa Clara  67221.000000
# 37      San Mateo  67115.333333
# 0         Alameda  58155.000000
# 28         Placer  56532.333333
# 5    Contra Costa  55670.000000
# 6       El Dorado  50694.333333
# 25           Napa  49905.333333
# 44         Sonoma  48300.666667

# %%
#act_agg_cnty2.sort_values(['med_income'], ascending=False).tail(10)
act_agg_cnty2.loc[:,["county","med_income"]].sort_values(['med_income'], ascending=False).tail(10)
# Out:
#       county    med_income
# 14      Lake  32497.000000
# 7     Fresno  32300.000000
# 47    Tehama  32182.333333
# 21    Merced  32119.666667
# 42  Siskiyou  32050.666667
# 17    Madera  31953.000000
# 22     Modoc  31377.333333
# 48   Trinity  31220.666667
# 49    Tulare  30138.666667
# 10  Imperial  26583.333333

# %% [markdown]
# #### Which CA Counties Have the Highest ACT Scores

# %%
#act_agg_cnty2.sort_values(['composite'], ascending=False).head(10)

act_agg_cnty2.loc[:,["county","composite"]].sort_values(['composite'], ascending=False).head(10)
# Out:
#          county  composite
# 18        Marin  25.159091
# 39  Santa Clara  24.864035
# 23         Mono  24.500000
# 41       Shasta  24.125000
# 26       Nevada  24.125000
# 28       Placer  24.087500
# 3     Calaveras  23.833333
# 9      Humboldt  23.785714
# 50     Tuolumne  23.750000
# 37    San Mateo  23.741071

# %%
#act_agg_cnty2.sort_values(['composite'], ascending=False).tail(10)
act_agg_cnty2.loc[:,["county","composite"]].sort_values(['composite'], ascending=False).tail(10)
# Out:
#       county  composite
# 10  Imperial  19.732143
# 8      Glenn  19.650000
# 49    Tulare  19.320000
# 7     Fresno  19.243902
# 21    Merced  18.802632
# 4     Colusa  18.666667
# 14      Lake  18.500000
# 13     Kings  18.475000
# 47    Tehama  18.107143
# 22     Modoc  16.850000

# %% [markdown]
# ##### <span style='color:blue'>_There is overlap between the lowest median income counties and the lowest composite ACT Score counties, for example:_ </span>
# - <span style='color:blue'>_Modoc is ranked last in composite score, and ranked 4th lowest median income._ </span>
# - <span style='color:blue'>_Imperial county has the lowest median income, and is ranked 10th from the bottom in composite score._ </span>
# - <span style='color:blue'>_Tehama, Lake, Merced are all also in in the bottom 10 of median income and composite score._ </span>
# ---

# %% [markdown]
# #### Do Lower Income Counties Have Lower Average Total ACT Scores?

# %%
# Let's make income and ACT scores into quartiles and crosstabulate them
# Categorization code mined/researched from Stack Overflow, ChatGPT, Pandas documentation
    # - https://pandas.pydata.org/docs/reference/api/pandas.qcut.html
    # - https://medium.com/swlh/categorical-data-in-pandas-9eaaff71e6f3
    # - https://towardsdatascience.com/all-pandas-qcut-you-should-know-for-binning-numerical-data-based-on-sample-quantiles-c8b13a8ed844
# Retbins to determine boundaries adopted from: https://note.nkmk.me/en/python-pandas-cut-qcut-binning/
    
quartiles_mi, bin_mi = pd.qcut(act_agg_cnty2['med_income'], q=4, labels=['0-25%', '25-50%', '50-75%', '75-100%'], retbins=True)

# Create a new column with the quartile labels
act_agg_cnty2['mi_group'] = quartiles_mi

# %%
quartiles_act, bin_act = pd.qcut(act_agg_cnty2['composite'], q=4, labels=['Group 1: Bottom 25%', 'Group 2', 'Group 3', 'Group 4: Top 25%'], retbins=True)

# Create a new column with the quartile labels
act_agg_cnty2['act_group'] = quartiles_act

# %%
for i, binn in enumerate(bin_mi):
    print(f"MI Bin {i}  ends at {round(binn)}")
# Out:
# MI Bin 0  ends at 26583
# MI Bin 1  ends at 34387
# MI Bin 2  ends at 38665
# MI Bin 3  ends at 44520
# MI Bin 4  ends at 71606

# %%
for i, binn in enumerate(bin_act):
    print(f"ACT Bin {i}  ends at {round(binn,3)}")
# Out:
# ACT Bin 0  ends at 16.85
# ACT Bin 1  ends at 20.022
# ACT Bin 2  ends at 22.297
# ACT Bin 3  ends at 23.5
# ACT Bin 4  ends at 25.159

# %%
pd.crosstab(act_agg_cnty2['mi_group'], act_agg_cnty2['act_group'])
# Out:
# act_group  Group 1: Bottom 25%  Group 2  Group 3  Group 4: Top 25%
# mi_group
# 0-25%                        9        2        2                 1
# 25-50%                       3        6        2                 2
# 50-75%                       1        3        4                 5
# 75-100%                      1        2        6                 5

# %%
#Lets look at how big the counties are / how many people each county makes up, rather than just the count of the county

# Look at number of students enrolled in schools across the counties
pd.crosstab(act_agg_cnty2['mi_group'], act_agg_cnty2['act_group'], values=act_agg_cnty2.n_enrolled, aggfunc=sum)
# Out:
# act_group  Group 1: Bottom 25%   Group 2   Group 3  Group 4: Top 25%
# mi_group
# 0-25%                 132900.0    7531.0    2971.0            3405.0
# 25-50%                 92427.0  492988.0    7663.0            6577.0
# 50-75%                 16520.0   61844.0  145512.0          158617.0
# 75-100%                13104.0    3247.0  133895.0          114838.0

# %%
act_agg_cnty2[(act_agg_cnty2['mi_group'] == "75-100%") & (act_agg_cnty2['act_group'] == "Group 1: Bottom 25%")]
# Out:
#            county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 34  San Francisco     13104.0       3234.0  20.277778  19.277778  20.277778
#
#       avg_sci  composite     population    med_income  latitude  longitude  \
# 34  19.722222  19.888889  889154.666667  67692.666667   37.7577  -122.4376
#
#    mi_group            act_group
# 34  75-100%  Group 1: Bottom 25%

# %%
act_agg_cnty2[(act_agg_cnty2['mi_group'] == "0-25%") & (act_agg_cnty2['act_group'] == "Group 4: Top 25%")]
# Out:
#      county  n_enrolled  n_testtaker  avg_read    avg_eng   avg_math  \
# 9  Humboldt      3405.0        321.0      25.0  23.285714  23.571429
#
#      avg_sci  composite     population    med_income   latitude   longitude  \
# 9  23.285714  23.785714  134778.666667  33384.333333  40.861485 -123.858512
#
#   mi_group         act_group
# 9    0-25%  Group 4: Top 25%

# %%
act_agg_cnty2[(act_agg_cnty2['mi_group'] == "25-50%") & (act_agg_cnty2['act_group'] == "Group 4: Top 25%")]
# Out:
#     county  n_enrolled  n_testtaker  avg_read    avg_eng   avg_math  avg_sci  \
# 23    Mono       664.0         60.0      26.0  24.666667  23.333333     24.0
# 41  Shasta      5913.0        516.0      25.5  23.375000  23.625000     24.0
#
#     composite     population    med_income   latitude   longitude mi_group  \
# 23     24.500   13706.666667  37542.000000  38.347100 -119.332727   25-50%
# 41     24.125  178057.000000  36003.666667  40.535022 -122.502164   25-50%
#
#            act_group
# 23  Group 4: Top 25%
# 41  Group 4: Top 25%

# %%
# Looking alos at the number of testtakes amongst enrolled students
pd.crosstab(act_agg_cnty2['mi_group'], act_agg_cnty2['act_group'], values=act_agg_cnty2.n_testtaker, aggfunc=sum)
# Out:
# act_group  Group 1: Bottom 25%  Group 2  Group 3  Group 4: Top 25%
# mi_group
# 0-25%                  17421.0   1410.0    249.0             321.0
# 25-50%                 16548.0  83362.0    726.0             576.0
# 50-75%                  3066.0  10344.0  28527.0           30549.0
# 75-100%                 3234.0    450.0  26569.0           24516.0

# %% [markdown]
# ##### <span style='color:blue'>_There does appear to be a relationship between median income group and ACT score group._<span style='color:blue'>
# - <span style='color:blue'>_There were 9 counties that were in the lowest median income group which were also in the lowest ACT score group. After counting the 9 counties by their size, it seems that they were sizeable counties._
# - <span style='color:blue'>_There were also 5 counties which were in the highest income group and the top ACT score group, these counties also accounted for a large number of enrolled students._ <span style='color:blue'>
# - <span style='color:blue'>_There were some anomalies, such as one county (SF), consisting of 13k students, which was in the highest median income group but the lowest ACT score group._<span style='color:blue'>
# - <span style='color:blue'>_There was one smaller county (Humboldt), consisting of 38k students, which was in the lowest median income group and the highest ACT score group. The Mono and Shasta counties together accounted for 75k students, and were also in a low median income group, but still in the top ACT score group._<span style='color:blue'>
#
# ##### <span style='color:blue'>_The number of testtakers, however, was fairly smaller than the number of students enrolled. The overall patterns remain, but it appears that the actual students in low income groups who scored the highest (and high income group students who scored the lowest) were far less than the figures rendered by counting student enrollment._<span style='color:blue'>
# ---

# %% [markdown]
# #### Do Larger Counties Have Higher Median Income and/or Higher ACT Scores?

# %%
# Using county population to look into this
# Let's categorize the population into Small, Medium, Large Counties
quintiles, bin_pop = pd.qcut(act_agg_cnty2['population'], q=5, labels=['Very Small', 'Small', 'Medium', 'Large', 'Very Large'], retbins=True)

# Create a new column with the quartile labels
act_agg_cnty2['pop_group'] = quintiles

# %%
for i, binn in enumerate(bin_pop):
    print(f"Pop Bin {i}  ends at {round(binn)}")
# Out:
# Pop Bin 0  ends at 9464
# Pop Bin 1  ends at 49413
# Pop Bin 2  ends at 154029
# Pop Bin 3  ends at 367980
# Pop Bin 4  ends at 895890
# Pop Bin 5  ends at 10234421

# %%
act_agg_cnty2['population'].describe()
# Out:
# count    5.400000e+01
# mean     7.349385e+05
# std      1.533029e+06
# min      9.463667e+03
# 25%      6.462825e+04
# 50%      2.206510e+05
# 75%      7.709167e+05
# max      1.023442e+07
# Name: population, dtype: float64

# %%
pd.crosstab(act_agg_cnty2['mi_group'], act_agg_cnty2['pop_group'])
# Out:
# pop_group  Very Small  Small  Medium  Large  Very Large
# mi_group
# 0-25%               3      5       3      1           2
# 25-50%              4      2       2      2           3
# 50-75%              3      2       2      3           3
# 75-100%             1      2       3      5           3

# %%
pd.crosstab(act_agg_cnty2['mi_group'], act_agg_cnty2['pop_group'], values=round(act_agg_cnty2.population), aggfunc=sum)
# Out:
# pop_group  Very Small     Small    Medium      Large  Very Large
# mi_group
# 0-25%         66893.0  505642.0  626668.0   476328.0   1918439.0
# 25-50%        83076.0  178041.0  398182.0  1315755.0  14830800.0
# 50-75%       100720.0  150892.0  494875.0  1744765.0   8083114.0
# 75-100%       30001.0  201669.0  728485.0  2990555.0   4761780.0

# %%
pd.crosstab(act_agg_cnty2['act_group'], act_agg_cnty2['pop_group'])
# Out:
# pop_group            Very Small  Small  Medium  Large  Very Large
# act_group
# Group 1: Bottom 25%           3      3       2      3           3
# Group 2                       3      3       2      2           3
# Group 3                       3      2       3      3           3
# Group 4: Top 25%              2      3       3      3           2

# %%
pd.crosstab(act_agg_cnty2['act_group'], act_agg_cnty2['pop_group'], values=round(act_agg_cnty2.population), aggfunc=sum)
# Out:
# pop_group            Very Small     Small    Medium      Large  Very Large
# act_group
# Group 1: Bottom 25%     60942.0  282384.0  468595.0  1808062.0   4093977.0
# Group 2                 92560.0  239547.0  379250.0  1315755.0  14195366.0
# Group 3                 68976.0  228642.0  771874.0  1389097.0   6146067.0
# Group 4: Top 25%        58212.0  285671.0  628491.0  2014489.0   5158723.0

# %% [markdown]
# ##### <span style='color:blue'>_There does not appear to be any obvious relationship between county size and either median income nor ACT score. This relationship will become more clear these variables are visualized against each other numericaly._</span>
# - <span style='color:blue'>_There do not appear to be any noteable differences in the number of counties per median income group by population group, suggesting that there is no concentration of, e.g., Large counties in the highest income group, or Small counties in the lowest income group._ </span>
#     - <span style='color:blue'>_The resident counts behind county distribution do not appear significantly different to eachother, but would need actual statistical procedures to confirm._ </span>
# - <span style='color:blue'>_There are 2-3 counties per ACT group by population group, suggesting that there is no concentration of, e.g., Large counties in the highest ACT score group, or Small counties in the lowest ACT score group._ </span>
#     - <span style='color:blue'>_The resident counts behind those 2-3 counties do not appear significantly different to eachother, but would need actual statistical procedures to confirm._ </span>
# ---

# %% [markdown]
# #### How Many Standard Deviations Above/Below is Each County's Median Income from the Mean Across All Counties (i.e., the Entire State)?

# %%
x = act_agg_cnty2.med_income
xbar = act_agg_cnty2.med_income.mean()
s = act_agg_cnty2.med_income.std()

# %%
z_mi = (x - xbar) / s

# %%
act_agg_cnty2['z_mi'] = z_mi

# %%
act_agg_cnty2.sort_values('z_mi', ascending=False).head(10)
# Out:
#            county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 18          Marin      7632.0       2259.0  26.181818  25.636364  24.545455
# 34  San Francisco     13104.0       3234.0  20.277778  19.277778  20.277778
# 39    Santa Clara     62283.0      12684.0  25.157895  24.929825  24.842105
# 37      San Mateo     21027.0       4302.0  24.178571  23.642857  23.785714
# 0         Alameda     49870.0      10864.0  23.654545  23.181818  23.345455
# 28         Placer     17506.0       3876.0  24.900000  23.900000  23.650000
# 5    Contra Costa     42271.0       9549.0  23.547619  22.714286  22.500000
# 6       El Dorado      6390.0       1395.0  24.250000  23.375000  23.625000
# 25           Napa      4903.0        627.0  23.000000  23.000000  22.142857
# 44         Sonoma     15248.0       2511.0  23.956522  23.086957  22.652174
#
#       avg_sci  composite    population    med_income   latitude   longitude  \
# ...

# %% [markdown]
# ##### <span style='color:blue'>_The Top 10 highest income counties represent standard deviations ranging from 0.66 to 2.91 higher than the state average. Most these counties appear to be Large or Very Large and are in the highest ACT score groups (except SF county)._</span>

# %%
act_agg_cnty2.sort_values('z_mi', ascending=False).tail(10)
# Out:
#       county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 14      Lake      1872.0        195.0  19.500000  18.166667  18.166667
# 7     Fresno     40821.0       5415.0  19.707317  18.463415  19.292683
# 47    Tehama      1888.0        906.0  18.428571  17.428571  18.428571
# 21    Merced     12518.0       1782.0  19.684211  18.157895  18.368421
# 42  Siskiyou      1264.0        285.0  21.333333  20.166667  20.666667
# 17    Madera      6267.0       1125.0  20.833333  19.916667  20.083333
# 22     Modoc       249.0        165.0  17.400000  15.000000  17.000000
# 48   Trinity       338.0         45.0  24.000000  24.000000  23.000000
# 49    Tulare     21283.0       2853.0  19.920000  18.560000  19.160000
# 10  Imperial      8646.0       1488.0  20.142857  19.285714  19.785714
#
#       avg_sci  composite    population    med_income   latitude   longitude  \
# 14  18.166667  18.500000  6.457367e+04  32497.000000  39.065005 -122.657019
# ...

# %% [markdown]
# ##### <span style='color:blue'>_The Bottom 10 lowest income counties represent standard deviations ranging from -0.86 to -1.43 below the state average. Half these counties appear to be Small or Very Small and are in the lowest ACT score groups._ </span>
# ---

# %% [markdown]
# #### How Many Standard Deviations Above/Below is Each County's ACT Score from the Mean Across All Counties (i.e., the Entire State)?

# %%
x = act_agg_cnty2.composite
xbar = act_agg_cnty2.composite.mean()
s = act_agg_cnty2.composite.std()

# %%
z_act = (x - xbar) / s

# %%
act_agg_cnty2['z_act'] = z_act

# %%
act_agg_cnty2.sort_values('z_act', ascending=False).head(10)
# Out:
#          county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 18        Marin      7632.0       2259.0  26.181818  25.636364  24.545455
# 39  Santa Clara     62283.0      12684.0  25.157895  24.929825  24.842105
# 23         Mono       664.0         60.0  26.000000  24.666667  23.333333
# 41       Shasta      5913.0        516.0  25.500000  23.375000  23.625000
# 26       Nevada      4390.0        228.0  25.000000  23.750000  24.250000
# 28       Placer     17506.0       3876.0  24.900000  23.900000  23.650000
# 3     Calaveras      1178.0         93.0  25.333333  22.666667  24.000000
# 9      Humboldt      3405.0        321.0  25.000000  23.285714  23.571429
# 50     Tuolumne      1272.0         69.0  26.000000  23.000000  23.000000
# 37    San Mateo     21027.0       4302.0  24.178571  23.642857  23.785714
#
#       avg_sci  composite    population    med_income   latitude   longitude  \
# 18  24.272727  25.159091  2.611247e+05  71605.666667  38.039526 -122.729951
# ...

# %% [markdown]
# ##### <span style='color:blue'>_The Top 10 highest ACT-scoring counties represent standard deviations ranging from ~1 to 1.67 above the state average. This list is represented by mostly Small or Medium sized counties, and also includes three counties which are in lower income groups._</span>

# %%
act_agg_cnty2.sort_values('z_act', ascending=False).tail(10)
# Out:
#       county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 10  Imperial      8646.0       1488.0  20.142857  19.285714  19.785714
# 8      Glenn      1257.0        216.0  20.600000  19.400000  18.600000
# 49    Tulare     21283.0       2853.0  19.920000  18.560000  19.160000
# 7     Fresno     40821.0       5415.0  19.707317  18.463415  19.292683
# 21    Merced     12518.0       1782.0  19.684211  18.157895  18.368421
# 4     Colusa       904.0         78.0  19.000000  17.333333  19.000000
# 14      Lake      1872.0        195.0  19.500000  18.166667  18.166667
# 13     Kings      5486.0        846.0  19.100000  17.900000  18.100000
# 47    Tehama      1888.0        906.0  18.428571  17.428571  18.428571
# 22     Modoc       249.0        165.0  17.400000  15.000000  17.000000
#
#       avg_sci  composite    population    med_income   latitude   longitude  \
# 10  19.714286  19.732143  1.883270e+05  26583.333333  33.077294 -114.751536
# ...

# %% [markdown]
# ##### <span style='color:blue'>_The Bottom 10 lowest ACT-scoring counties represent standard deviations ranging from nearly -1 to -2.42 below the state average. This list is represented by mostly Small or Very Small sized counties, and all counties are in lower income groups, with a majority being in the lowest group._</span>
# ---

# %% [markdown]
# #### Among Those Scoring Low on the SAT, What Is Their Average High School (HS) GPA vs. Freshmen Year (FY) GPA

# %%
# Defining "low" as below the median total SAT score for the sample
# filter to low scores
low_sat = ets[ets['sat_total'] < ets['sat_total'].median()]
print(f"The HS GPA is {round(low_sat.gpa_hs.mean(),3)} and the FY GPA is {round(low_sat.gpa_fy.mean(),3)}")
# Out:
# The HS GPA is 3.013 and the FY GPA is 2.197

# %%
# filter to high scores
high_sat = ets[ets['sat_total'] > ets['sat_total'].median()]
print(f"The HS GPA is {round(high_sat.gpa_hs.mean(),3)} and the FY GPA is {round(high_sat.gpa_fy.mean(),3)}")
# Out:
# The HS GPA is 3.378 and the FY GPA is 2.741

# %%
# Look at Top and Bottom 25% (numbers taken from summary statistics)
bottom25_sat = ets[ets['sat_total'] < ets['sat_total'].quantile(.25)]
print(f"The HS GPA is {round(bottom25_sat.gpa_hs.mean(),3)} and the FY GPA is {round(bottom25_sat.gpa_fy.mean(),3)}")
# Out:
# The HS GPA is 2.889 and the FY GPA is 2.035

# %%
top25_sat = ets[ets['sat_total'] > ets['sat_total'].quantile(.75)]
print(f"The HS GPA is {round(top25_sat.gpa_hs.mean(),3)} and the FY GPA is {round(top25_sat.gpa_fy.mean(),3)}")
# Out:
# The HS GPA is 3.497 and the FY GPA is 2.948

# %% [markdown]
# ##### <span style='color:blue'>_There appears to be a relationship between SAT score and HS GPA vs. FY GPA, though it needs to be delved into more deeply (using correlations, visualization, etc.)_</span>
# - <span style='color:blue'>_Among students who scored in the bottom 50% of the SAT, their HS GPA was larger than their FY GPA by a factor of ~0.82._</span>
# - <span style='color:blue'>_Among students scoring in the Top 50% of the SAT, their FY GPA was generally higher and slightly closer to their HS GPA, but still lower than their HS GPA by a factor of ~0.64._</span>
# - <span style='color:blue'>_Looking at the Bottom 25% and the Top 25%, FY GPA still appeared lower than HS GPA, though not by as much of a factor for higher SAT scorers._</span>
#     - <span style='color:blue'> _It is possible that those scoring higher on the SAT got into more rigorous colleges, where higher GPA is harder to achieve._ </span>
# ---

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ---
# ### Distribution of Main Variables of Interest
# ---

# %%
# Histograms
plt.figure(figsize = (10, 5))
sns.histplot(act_agg_cnty2['med_income'], color = 'teal', bins = 10, kde=True) # colors: https://matplotlib.org/stable/gallery/color/named_colors.html, kde: https://seaborn.pydata.org/generated/seaborn.histplot.html

# Create a descriptive title
plt.title('Distribution of Median Income (Three-Year-Average) per County in California')
plt.xlabel("Median Income");

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: The three-year-average median income is right-skewed. Most counties fall below the $40K bin, but some go up to $70K. The distribution of all California residnet medium incomes may look more normal than what is shown here as this is county level data._ </span>

# %%
plt.figure(figsize = (10, 5))
sns.histplot(act_agg_cnty2['composite'], color = 'royalblue', bins = 10, kde=True) # colors: https://matplotlib.org/stable/gallery/color/named_colors.html

# Create a descriptive title
plt.title('Distribution of Composite ACT Score per County in California')
plt.xlabel("Composite ACT Score");

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: The distribution of ACT scores by California county is bimodal and indicates that there are approximately 12 counties where the test-taking students are scoring on the higher end of the test, relative to the California range. There are also 8 counties where the average SAT score is towards the lower end of score average across the state. Overall, there are only few counties scoring very low on the test._ </span>

# %%
# Size
plt.figure(figsize = (25, 5))

# Bar chart
sns.barplot(x = act_agg_cnty2['county'], y = act_agg_cnty2['med_income'], order = act_agg_cnty2.sort_values('med_income', ascending=False).county, palette = 'Spectral') # https://seaborn.pydata.org/tutorial/color_palettes.html, sorting help: https://www.geeksforgeeks.org/seaborn-sort-bars-in-barplot/

# Create a descriptive title
plt.title('Median Income by County in California', fontsize=18)

# Rotate text
plt.xticks(rotation = 85)

# Add axis labels
plt.xlabel('California County', fontsize=13)
plt.ylabel('Median Income', fontsize=13); # semicolon suppresses text output

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: There are 54 counties with test-taking students and the spread of incomes between the highest and lowest is sizeable (~$40K), but most counties seen in the middle of the distribution are comparable in median income._ </span>

# %%
# Boxplots
# Melt data frame - adopted from
    # - https://www.statology.org/seaborn-boxplot-multiple-columns/ 
    # - https://towardsdatascience.com/wide-to-long-data-how-and-when-to-use-pandas-melt-stack-and-wide-to-long-7c1e0f462a98
    
box_gpa = ets.drop(columns=['sex', 'sat_total', 'gpa_hs', 'gpa_fy'])
box_gpa_melt = pd.melt(box_gpa)

# %%
# Boxplots by group
sns.boxplot(x='variable', y='value', data=box_gpa_melt)

plt.title("SAT Scores Distribution Among 1,000 Student Sample")
plt.xlabel('SAT Section')
plt.ylabel('SAT Score (Divided by 100)');

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: Overall, students scored higher on SAT math than SAT verbal, the median scores were approximately 500 and 550, respectively, and there was a large range in scores. The distribution of scores may be impacted when looking at subcohorts, as is done in the boxplot below._ </span>

# %%
top_fy_gpas = ets[ets['gpa_fy'] > ets['gpa_fy'].quantile(.75)]
box_gpa = top_fy_gpas.drop(columns=['sex', 'sat_total', 'gpa_hs', 'gpa_fy'])
box_gpa_melt = pd.melt(box_gpa)
sns.boxplot(x='variable', y='value', data=box_gpa_melt);

plt.title("SAT Scores Distribution Among Sampled Students \n with the Top 25% of FY GPAs ")
plt.xlabel('SAT Section')
plt.ylabel('SAT Score (Divided by 100)');

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: Among students who had the Top 25% of FY GPAs in the sample, the SAT score distributions were higher than the overall sampled cohort. This may indicate that higher FY GPA could be predicted by higher SAT scores._ </span>

# %% [markdown]
# ---
# ### ACT Score and Median Income Visualizations
# ---

# %%
act_agg_cnty2.head()
# Out:
#       county  n_enrolled  n_testtaker   avg_read    avg_eng   avg_math  \
# 0    Alameda     49870.0      10864.0  23.654545  23.181818  23.345455
# 1     Amador       845.0        111.0  24.000000  23.000000  23.000000
# 2      Butte      7225.0        678.0  22.700000  21.500000  23.100000
# 3  Calaveras      1178.0         93.0  25.333333  22.666667  24.000000
# 4     Colusa       904.0         78.0  19.000000  17.333333  19.000000
#
#      avg_sci  composite    population    med_income   latitude   longitude  \
# 0  22.927273  23.277273  1.661968e+06  58155.000000  37.720226 -122.164352
# 1  22.250000  23.062500  3.770933e+04  43032.333333  38.472162 -120.574195
# 2  22.500000  22.450000  2.201253e+05  35009.666667  39.591273 -121.672882
# 3  23.333333  23.833333  4.450467e+04  42176.000000  38.254627 -120.465738
# 4  19.333333  18.666667  2.232233e+04  36243.666667  39.167981 -122.299067
#
#   mi_group            act_group   pop_group      z_mi     z_act
# ...

# %%
act_agg_cnty2['pop_group'].value_counts()
# Out:
# Very Small    11
# Small         11
# Large         11
# Very Large    11
# Medium        10
# Name: pop_group, dtype: int64

# %%
for i, binn in enumerate(bin_pop):
    print(f"Pop Bin {i}  ends at {round(binn)}")
# Out:
# Pop Bin 0  ends at 9464
# Pop Bin 1  ends at 49413
# Pop Bin 2  ends at 154029
# Pop Bin 3  ends at 367980
# Pop Bin 4  ends at 895890
# Pop Bin 5  ends at 10234421

# %%
#Scatterplot

# Size
plt.figure(figsize = (8, 5))

# Update labels
label_map = {'Very Small': '<50K',
             'Small': '50K to <154K',
             'Medium': '154K to <368K',
             'Large': '368K to <900K',
             'Very Large': '900K+'
}

act_agg_cnty2['descrip_pop_group'] = act_agg_cnty2['pop_group'].map(label_map)

sns.scatterplot(x = act_agg_cnty2['composite'], y = act_agg_cnty2['med_income'], hue = act_agg_cnty2['descrip_pop_group'], palette = 'inferno')

# Create a descriptive title
plt.title('Higher Median Incomes Moderately Correlate with Higher\n ACT Scores Across California Counties', fontsize = 15)

# Add axis labels
plt.xlabel('Composite ACT Score by County')
plt.ylabel('Median Income (Three-Year Average)')

plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0, title = 'Size of County \n(# of Residents)' ); 
#code adapted from https://www.statology.org/seaborn-legend-outside/

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: The above image shows that there tends to be a positive relationship between income and ACT score. Generally speaking, the higher a counties median income, the better that county will do on the ACT on average. There are instances where county students are achieving higher ACT score despite having lower median incomes, as represented by any data points that fall below or near the upper right quadrant._ </span>
#
# ##### <span style='color:blue'>_The largest sized counties (yellow data points, 900K+ residents) appear to have the strongest positive correlation between median income and ACT score. The second largest counties (orange data points, >368K residents) also look like they have a positive correlation. The third largest counties look like they have a stronger correlation than the two smallest ones._ </span>
#
# <span style='color:blue'>_Note: The cutoffs for county size groupings were determined by arranging all 54 counties in ascending order of population size and dividing them into five groups such that each represented an equal number of counties._</span>

# %%
# Heatmap

# Size
plt.figure(figsize = (12,6))

heat_act = act_agg_cnty2.drop(columns=['z_mi', 'z_act', 'latitude', 'longitude', 'n_enrolled', 'n_testtaker'])

# Get correlation of variables.
corr = heat_act.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, 
            mask = mask, 
            square = True, 
            cmap = 'coolwarm', 
            annot = True, 
            vmin = -1, 
            vmax = 1)

plt.title("Modest Correlation Between\n Median Income and ACT Score", fontsize =15);
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_31892\2679645587.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = heat_act.corr()

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: Different testing components all have high correlations to each other, suggesting that if a student does well on one section, it is a good predictor of their performance overall. The composite score is an accurate estimation of how each section went for most students. There is a moderate correlation between income and ACT score (0.53), and a slightly higher correlation between median income and the ACT math score._ </span>

# %%
# Heatmap After Filtering to Largest counties

# Size
plt.figure(figsize = (12,6))

heat_act = act_agg_cnty2.drop(columns=['z_mi', 'z_act', 'latitude', 'longitude', 'n_enrolled', 'n_testtaker'])
heat_act_large = heat_act[(heat_act.pop_group == "Very Large") ]

# Get correlation of variables.
corr = heat_act_large.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, 
            mask = mask, 
            square = True, 
            cmap = 'coolwarm', 
            annot = True, 
            vmin = -1, 
            vmax = 1)

plt.title("Strong Correlation Between Median Income and ACT Score \n When Filtering to Largest Counties", fontsize =15);
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_31892\298377471.py:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = heat_act_large.corr()

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: When filtering the county data to the largest counties, there appears to be a strong correlation between median income and ACT score. This may indicate that socioeconomic factors, such as resources, may be more fairly distributed across these counties for better outcomes._ </span>

# %%
# Same for Medium counties
# Size
plt.figure(figsize = (12,6))

heat_act = act_agg_cnty2.drop(columns=['z_mi', 'z_act', 'latitude', 'longitude', 'n_enrolled', 'n_testtaker'])
heat_act_medium = heat_act[heat_act.pop_group == "Medium"]

corr = heat_act_medium.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, 
            mask = mask, 
            square = True, 
            cmap = 'coolwarm', 
            annot = True, 
            vmin = -1, 
            vmax = 1)

plt.title("Strong Correlation Between Median Income and ACT Score \n When Filtering to Medium Counties", fontsize =15);
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_31892\456078879.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = heat_act_medium.corr()

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: When filtering the county data to the medium-sized counties, there still appears to be a strong correlation between median income and ACT score, but not as high as the largest counties. This suggests the smaller the population of a county, the less the association is between income and ACT score, perhaps because the distributions of incomes also decrease._ </span>

# %%
# Same for Small counties
# Size
plt.figure(figsize = (12,6))

heat_act = act_agg_cnty2.drop(columns=['z_mi', 'z_act', 'latitude', 'longitude', 'n_enrolled', 'n_testtaker'])
heat_act_small = heat_act[(heat_act.pop_group == "Very Small") | (heat_act.pop_group == "Small")]

corr = heat_act_small.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, 
            mask = mask, 
            square = True, 
            cmap = 'coolwarm', 
            annot = True, 
            vmin = -1, 
            vmax = 1)

plt.title("Milder Correlation Between Median Income and ACT Score \n When Filtering to Smallest Counties", fontsize =15);
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_31892\3262840728.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = heat_act_small.corr()

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: The above images confirm that there is a positive moderate correlation between Median Income and ACT score in California counties._ </span>
# - <span style='color:blue'>_The overall correlation is moderate with a correlation coefficient of 0.53, though when looking at just math this increases slightly to 0.56. This suggess that math in particular, if one of the subject areas had to be chosen, may benefit most from additional resource or policies._</span>
# - <span style='color:blue'>_The correlation is very strong when filtering to the largest counties (correlation coefficient of 0.91), still strong when filtering to medium sized counties (0.77), and less strong when looking at the smallest counties (0.4). This decreasing correlation may occur when the distributions of incomes within the county are smaller._</span>
# - <span style='color:blue'>_The different subject tests were strongly positively correlated with eachother, meaning the performace of a student on one subject area was a good indicator of overall performance._</span>
# - <span style='color:blue'>_Median income had nearly the same correlation with each subject test._</span>

# %% [markdown]
# ---
# ### High School GPA vs. College GPA and SAT Performance
# ---

# %%
# Size
plt.figure(figsize = (11, 5))

sns.scatterplot(x = ets['gpa_hs'], y = ets['gpa_fy'], hue = ets['sex'], palette = 'Dark2')

# Create a descriptive title
plt.title('High School GPA Has a Scattered Relationship with Freshmen-Year-College GPA', fontsize = 15)

# Add axis labels
plt.xlabel('High School GPA')
plt.ylabel('Freshmen-Year-College GPA)');

plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0, title = 'Sex');

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: The above scatterplot shows that there is a moderate positive correlation between between Freshmen Year (FY) GPA and High School (HS) GPA. There does not appear to be a meaningful difference between males and females in this distribution, except that there appear to be more females towards the higher end of the relationship. This may suggest females have a higher association between their college performance and HS performance._ </span>

# %%
# low_college = ets[ets['gpa_fy'] < ets['gpa_fy'].quantile(0.33333)]
# med_college = ets[(ets['gpa_fy'] > ets['gpa_fy'].quantile(0.33333)) & (ets['gpa_fy'] < ets['gpa_fy'].quantile(0.67333))]
# hi_college = ets[ets['gpa_fy'] > ets['gpa_fy'].quantile(0.67333)]

# Code below is adopted from Statology on categorical variables: https://www.statology.org/pandas-create-categorical-variable/
# Calculate quantiles for FYA GPA
thirds = np.percentile(ets['gpa_fy'], [0, 33, 66, 100])

# Create a new column 'GPA Category' based on quantiles
ets['gpa_fy_cat'] = pd.cut(ets['gpa_fy'], thirds, labels=['Lowest 33% of FY GPAs', 'Middle 33% of FY GPAs', 'Top 33% of FY GPAs'])

# %%
# Size
plt.figure(figsize = (11, 5))

sns.scatterplot(x = ets['sat_total'], y = ets['gpa_hs'], hue = ets['gpa_fy_cat'], palette = 'Dark2')

# Create a descriptive title
plt.title('High School GPA Has a Moderate Relationship with SAT Score', fontsize = 15)

# Add axis labels
plt.xlabel('SAT Total Score')
plt.ylabel('High School GPA')

plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0, title = 'Freshmen-Year-College Performance'); 
#code adapted from https://www.statology.org/seaborn-legend-outside/

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: There is a moderate positive correlation between HS GPA and SAT score. This relationship seems to be the highest among students who also ended up being in the Top 33% of FY GPAs among the sampled cohort. This suggests that for students aiming to have the top FY GPAs, high SAT scores as well as high GPAs may be important metrics to achieve._ </span>

# %%
# Find Top 33% of HS performers, middle 33%, and bottom 33%

#code below is adopted from Statology on categorical variables: https://www.statology.org/pandas-create-categorical-variable/
# Calculate quantiles for HS GPA
thirds = np.percentile(ets['gpa_hs'], [0, 33, 66, 100])

# Create a new column 'GPA Category' based on quantiles
ets['gpa_hs_cat'] = pd.cut(ets['gpa_hs'], thirds, labels=['Lowest 33% of HS GPAs', 'Middle 33% of HS GPAs', 'Top 33% of HS GPAs'])

# %%
# Size
plt.figure(figsize = (11, 5))

sns.scatterplot(x = ets['sat_total'], y = ets['gpa_fy'], hue = ets['gpa_hs_cat'], palette = 'Dark2')

# Create a descriptive title
plt.title('SAT Score Has a Modest Relationship with Freshmen-Year-College GPA', fontsize = 15)

# Add axis labels
plt.xlabel('SAT Total Score')
plt.ylabel('Freshmen Year GPA)');

plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0, title = 'High School Performance' ); 
#code adapted from https://www.statology.org/seaborn-legend-outside/

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: There is a slightly higher moderate positive correlation between FY GPA and SAT score (than the previous figure of HS GPA and SAT score). This is most prominent among students who had top HS GPAs, and is weaker of an association for students who had lower HS GPAs. There are few students who achieved high FY GPAs who had low SAT scores, suggesting that the SAT may be a good predictor of college performance._ </span>

# %%
# Heat Map
# Establish size of figure.
plt.figure(figsize = (12,5))

# Get correlation of variables.
corr = ets.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, 
            mask = mask, 
            square = True, 
            cmap = 'coolwarm', 
            annot = True, 
            vmin = -1, 
            vmax = 1);
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_31892\46618782.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = ets.corr()

# %% [markdown]
# ##### <span style='color:blue'>_Interpretation: As seen visually in the scatterplots, the above heatmap confirms that there is a moderate positive correlation between HS GPA, Freshmen-Year-College GPA, and SAT score. The correlation coefficient of 0.54 indicates that HS GPA may be able to predict college GPA, and based on this data, that prediction may be better than using the SAT score. The correlations between SAT score and HS/FY GPA (0.43 and 0.46, respectively) suggest that doing well on one may predict the other, but these two factors by themselves may not be strongest predcitors of performance._ </span>

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Based on this exploration, there are two main conclusions drawn in relation to our original problem statement.
#
# 1. There appears to be a moderate positive correlation (R = 0.53) between median income and ACT score for California counties.
#     - This correlation gets stronger for larger counties - the largest counties (900K+ residents) had a strong linear correlation (R = 0.91)
#     - The correlation is strong, but milder, for medium sized counties (0.77) and weaker, comparatively, for small counties (R = 0.40)
#
#
#     __Recommendation:__ Larger counties have a wider range of socioeconomic backgrounds, social disparities, and inequalities, making the correlation between ACT scores and median income more prominent in these areas. We recommend that larger counties invest more resources in access to SAT/ACT preparatory resources and, most importantly, school-funding to assure students across all schools are prepared for post-high-school studies. This would improve outcomes for not only college performance, but allow the SAT/ACT to be additional positive data points for students to present during college admissions.
#
# 2. High School GPA and SAT scores both have scattered and modest relationships with first-year college performance.
#     - This relationship looked slightly stronger for females than males.
#     - Among the student sample data (n = 1000), HS GPA had a slightly stronger correlation to FY GPA than SAT score did (0.54 vs. 0.46).
#     - The relationship between SAT score and FY college performance had the highest correlation for students who were higher performers in high school. This suggests that, for the most part, high HS GPA coupled with strong SAT scores were the best predictor of college success.
#
#
#     __Recommendation:__ There is not enough data to say definitively that either the SAT or HS GPA are more accurate or best predictors of success in college. By and large, both coupled together still appear to be strong indicators of college success. Higher FY GPAs among students who had high HS GPAs and good SAT scores make retention and graduation more likely. We recommend UC schools consider bringing standardized testing back into their schools by 2025, the time period in which they intend to completely eliminate the test for admissions processes. The data looked at in this exploration is largely California data, but students seek admissions to UC schools from all over the world - therefore, an additional factor that is more standardize than HS GPA may be beneficial in admitting the best-fit students.
